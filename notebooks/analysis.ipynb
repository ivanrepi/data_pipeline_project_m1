# %%
import pandas as pd
import numpy as np
import json

# %%
bicimad_stations=pd.read_csv("../data/raw/bicimad_stations.csv").drop_duplicates()
instalaciones=pd.read_csv("../data/raw/instalaciones_deportivas_madrid.csv", sep=";").drop_duplicates()

# %%
instalaciones.head()
# Out:
#          PK                                             NOMBRE  \
# 0  11353987  Instalación Deportiva  Básica Embalse de San Juan
# 1   6344681       Instalación Deportiva Básica Alto del Retiro
# 2  11350944  Instalación Deportiva Básica Avenida de Cerro ...
# 3  11350990  Instalación Deportiva Básica Avenida de las Su...
# 4  11350948  Instalación Deportiva Básica Avenida del Ensan...
#
#   DESCRIPCION-ENTIDAD HORARIO  \
# 0                 NaN     NaN
# 1                 NaN     NaN
# 2                 NaN     NaN
# 3                 NaN     NaN
# 4                 NaN     NaN
#
#                                         EQUIPAMIENTO  \
# 0         Pista de baloncesto. Pista de fútbol sala.
# 1  Pista polideportiva (marcajes de fútbol sala y...
# 2       Pista de minibaloncesto. Pista de minifútbol
# 3  Pista de baloncesto. Pista polideportiva (marc...
# 4  Pista de minibaloncesto. Pista de minifútbol. ...
#
#                                TRANSPORTE DESCRIPCION  ACCESIBILIDAD  \
# 0  Bus: 58 , 63 , 145Renfe: Santa Eugenia         NaN              0
# 1                      Metro: Las Suertes         NaN              0
# 2                 Metro: CongostoBus: 142         NaN              0
# 3                      Metro: Las Suertes         NaN              0
# 4                      Metro: Las Suertes         NaN              0
#
#                                          CONTENT-URL              NOMBRE-VIA  \
# 0  http://www.madrid.es/sites/v/index.jsp?vgnextc...     EMBALSE DE SAN JUAN
# 1  http://www.madrid.es/sites/v/index.jsp?vgnextc...         ALTO DEL RETIRO
# 2  http://www.madrid.es/sites/v/index.jsp?vgnextc...            CERRO MILANO
# 3  http://www.madrid.es/sites/v/index.jsp?vgnextc...  avenida de las Suertes
# 4  http://www.madrid.es/sites/v/index.jsp?vgnextc...    ENSANCHE DE VALLECAS
#
#    ...           DISTRITO COORDENADA-X COORDENADA-Y    LATITUD  LONGITUD  \
# 0  ...  VILLA DE VALLECAS     449213.0    4468179.0  40.362643 -3.598148
# 1  ...  VILLA DE VALLECAS     450057.0    4468715.0  40.367515 -3.588265
# 2  ...  VILLA DE VALLECAS     447502.0    4468855.0  40.368619 -3.618357
# 3  ...  VILLA DE VALLECAS     448037.0    4469037.0  40.370297 -3.612067
# 4  ...  VILLA DE VALLECAS     448037.0    4469037.0  40.370297 -3.612067
#
#    TELEFONO FAX EMAIL                                               TIPO  \
# 0       NaN NaN   NaN  /contenido/entidadesYorganismos/CentrosEspacio...
# 1       NaN NaN   NaN  /contenido/entidadesYorganismos/CentrosEspacio...
# 2       NaN NaN   NaN  /contenido/entidadesYorganismos/CentrosEspacio...
# 3       NaN NaN   NaN  /contenido/entidadesYorganismos/CentrosEspacio...
# 4       NaN NaN   NaN  /contenido/entidadesYorganismos/CentrosEspacio...
#
#    Unnamed: 30
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 31 columns]

# %%
bicimad_stations.head()
# Out:
#    id                name  light number  \
# 0   1    Puerta del Sol A      2     1a
# 1   2    Puerta del Sol B      1     1b
# 2   3         Miguel Moya      2      2
# 3   4  Plaza Conde Suchil      0      3
# 4   5            Malasaña      2      4
#
#                                     address  activate  no_available  \
# 0                       Puerta del Sol nº 1         1             0
# 1                       Puerta del Sol nº 1         1             0
# 2                    Calle Miguel Moya nº 1         1             0
# 3  Plaza del Conde del Valle de Súchil nº 3         1             0
# 4               Calle Manuela Malasaña nº 5         1             0
#
#    total_bases  dock_bikes  free_bases  reservations_count geometry_type  \
# 0           30          15          11                   0         Point
# 1           30          22           4                   0         Point
# 2           24          12          11                   0         Point
# 3           18           4          11                   0         Point
# 4           24          12          12                   0         Point
#
#                       geometry_coordinates
# 0                 [-3.7018341, 40.4172137]
# 1  [-3.701602938060457, 40.41731271011562]
# 2                 [-3.7058415, 40.4205886]
# 3                 [-3.7069171, 40.4302937]
# 4                 [-3.7025875, 40.4285524]

# %%
coordinates_stations = [i.split(",") for i in bicimad_stations["geometry_coordinates"]]
longitud = [float(j[0].replace("[","").strip()) for j in coordinates_stations]
latitud = [float(j[1].replace("]","").strip()) for j in coordinates_stations]
bicimad_stations["latitude"]=latitud
bicimad_stations["longitude"]=longitud

bicimad_stations["latitude"]=pd.to_numeric(bicimad_stations["latitude"])
bicimad_stations["longitude"]=pd.to_numeric(bicimad_stations["longitude"])

bicimad_stations
# Out:
#       id                    name  light number  \
# 0      1        Puerta del Sol A      2     1a
# 1      2        Puerta del Sol B      1     1b
# 2      3             Miguel Moya      2      2
# 3      4      Plaza Conde Suchil      0      3
# 4      5                Malasaña      2      4
# ..   ...                     ...    ...    ...
# 259  266  Ciudad Universitaria 1      0    258
# 260  267  Ciudad Universitaria 2      2    259
# 261  268       Facultad Biología      2    260
# 262  269        Facultad Derecho      0    261
# 263  270                 Zurbano      0    247
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ..                                                 ...       ...
# 259  Avenida de la Complutense (Metro Ciudad Univer...         1
# 260  Avenida de la Complutense (Metro Ciudad Univer...         1
# 261          Calle José Antonio Novais frente al nº 12         1
# 262                          Avenida Complutense nº 23         1
# 263                                Calle Zurbano nº 90         1
#
#      no_available  total_bases  dock_bikes  free_bases  reservations_count  \
# 0               0           30          15          11                   0
# 1               0           30          22           4                   0
# 2               0           24          12          11                   0
# 3               0           18           4          11                   0
# 4               0           24          12          12                   0
# ..            ...          ...         ...         ...                 ...
# 259             0           24           0          24                   0
# 260             0           24          12          12                   0
# 261             0           24           9          14                   0
# 262             0           24           5          18                   0
# 263             0           24           6          15                   0
#
#     geometry_type                     geometry_coordinates   latitude  \
# 0           Point                 [-3.7018341, 40.4172137]  40.417214
# 1           Point  [-3.701602938060457, 40.41731271011562]  40.417313
# 2           Point                 [-3.7058415, 40.4205886]  40.420589
# 3           Point                 [-3.7069171, 40.4302937]  40.430294
# 4           Point                 [-3.7025875, 40.4285524]  40.428552
# ..            ...                                      ...        ...
# 259         Point                     [-3.72699, 40.44375]  40.443750
# 260         Point                     [-3.72693, 40.44342]  40.443420
# 261         Point                 [-3.7272945, 40.4483322]  40.448332
# 262         Point                     [-3.72937, 40.45109]  40.451090
# 263         Point                     [-3.69281, 40.43837]  40.438370
#
#      longitude
# 0    -3.701834
# 1    -3.701603
# 2    -3.705842
# 3    -3.706917
# 4    -3.702587
# ..         ...
# 259  -3.726990
# 260  -3.726930
# 261  -3.727295
# 262  -3.729370
# 263  -3.692810
#
# [264 rows x 15 columns]

# %%
from shapely.geometry import Point
import geopandas as gpd   # conda install -c conda-forge geopandas

def to_mercator(lat, long):
    # transform latitude/longitude data in degrees to pseudo-mercator coordinates in metres
    c = gpd.GeoSeries([Point(lat, long)], crs=4326)
    c = c.to_crs(3857)
    return c

def distance_meters(lat_start, long_start, lat_finish, long_finish):
    # return the distance in metres between to latitude/longitude pair point in degrees (i.e.: 40.392436 / -3.6994487)
    start = to_mercator(lat_start, long_start)
    finish = to_mercator(lat_finish, long_finish)
    return start.distance(finish)

# %%
nearest_distance=pd.DataFrame(columns=["pk_ins","nombre_ins","ins_latitude","ins_longitude","bicimad_latitude","bicimad_longitude","distance","name_station","address_station","id"])

for i in instalaciones.index:
    a=(float(instalaciones["LATITUD"][i]))
    b=(float(instalaciones["LONGITUD"][i]))
    pk=instalaciones["PK"][i]
    nombre=instalaciones["NOMBRE"][i]

    distance=pd.DataFrame(columns=["distance","latitude","longitude"])

    for j in bicimad_stations.index:
        c=(float(bicimad_stations["latitude"][j]))
        d=(float(bicimad_stations["longitude"][j]))
        name=bicimad_stations["name"][j]
        address=bicimad_stations["address"][j]
        id_station=bicimad_stations["id"][j]
        e=distance_meters(a, b, c, d)

        distance=distance.append({"distance":e[0],"latitude":c,"longitude":d,"name":name,"address":address,"id":id_station},ignore_index=True)

    nearest_station=distance.iloc[distance["distance"].idxmin()]
    nearest_distance=nearest_distance.append({"pk_ins":pk,"nombre_ins":nombre,"ins_latitude":a,"ins_longitude":b,"bicimad_latitude":nearest_station[1],"bicimad_longitude":nearest_station[2],"distance":nearest_station[0],"name_station":nearest_station[3],"address_station":nearest_station[4],"id":nearest_station[5]},ignore_index=True)

nearest_distance.to_csv("../data/processed/nearest_stations.csv", index=False)

# %%
nearest_distance
# Out:
#        pk_ins                                  Place of interest  \
# 0    11353987  Instalación Deportiva  Básica Embalse de San Juan
# 1     6344681       Instalación Deportiva Básica Alto del Retiro
# 2    11350944  Instalación Deportiva Básica Avenida de Cerro ...
# 3    11350990  Instalación Deportiva Básica Avenida de las Su...
# 4    11350948  Instalación Deportiva Básica Avenida del Ensan...
# ..        ...                                                ...
# 508   6280408  Instalación Deportiva Municipal Rocódromo 'Roc...
# 509     38383  Instalación deportiva municipal básica Campo d...
# 510  10967962                Parque Lineal UZI 0.06 Arroyofresno
# 511  10967954                    Pista de Patinaje Paco de Lucía
# 512  10967959      Pista de petanca Centro de Mayores La Vaguada
#
#      ins_latitude  ins_longitude  bicimad_latitude  bicimad_longitude  \
# 0       40.362643      -3.598148         40.400368          -3.634587
# 1       40.367515      -3.588265         40.400368          -3.634587
# 2       40.368619      -3.618357         40.400368          -3.634587
# 3       40.370297      -3.612067         40.400368          -3.634587
# 4       40.370297      -3.612067         40.400368          -3.634587
# ..            ...            ...               ...                ...
# 508     40.399273      -3.718824         40.398247          -3.716591
# 509           NaN            NaN         40.417214          -3.701834
# 510     40.487147      -3.732863         40.451090          -3.729370
# 511     40.385278      -3.764155         40.409136          -3.728534
# 512     40.479033      -3.708264         40.463028          -3.697333
#
#           distance                  Station location  Station ID  \
# 0     5.844283e+03  Calle Hacienda de Pavones nº 342       229.0
# 1     6.330202e+03  Calle Hacienda de Pavones nº 342       229.0
# 2     3.970966e+03  Calle Hacienda de Pavones nº 342       229.0
# 3     4.185104e+03  Calle Hacienda de Pavones nº 342       229.0
# 4     4.185104e+03  Calle Hacienda de Pavones nº 342       229.0
# ..             ...                               ...         ...
# 508   2.740282e+02  Glorieta Marqués de Vadillo nº 9       220.0
# 509  1.797693e+308               Puerta del Sol nº 1         1.0
# 510   4.032666e+03         Avenida Complutense nº 23       269.0
# 511   4.779660e+03              Calle Caramuel nº 51       232.0
# 512   2.159006e+03               Calle Azucenas nº 1       215.0
#
#         BiciMAD station
# 0               Pavones
# 1               Pavones
# 2               Pavones
# 3               Pavones
# 4               Pavones
# ..                  ...
# 508  Marqués de Vadillo
# 509    Puerta del Sol A
# 510    Facultad Derecho
# 511            Caramuel
# 512             Remonta
#
# [513 rows x 10 columns]

# %%
#Eliminar esta primera fila cuando haya corregido el error del nombre de las columnas
nearest_distance.rename(columns={"nombre_ins":"Place of interest","name_station":"Station location","address_station":"Station ID","id":"BiciMAD station"}, inplace=True)

# %%
ins_nearest_stations=instalaciones.merge(nearest_distance,left_on="PK",right_on="pk_ins") #Merge instalaciones with the table obtained in the previous step, to get the address and the rest of information from instalaciones table
ins_nearest_stations.dropna(subset = ["LATITUD","LONGITUD"], inplace=True) #Drop the rows where we have not latitude and longitude of the Sports installation
ins_nearest_stations.head()
# Out:
#          PK                                             NOMBRE  \
# 0  11353987  Instalación Deportiva  Básica Embalse de San Juan
# 1   6344681       Instalación Deportiva Básica Alto del Retiro
# 2  11350944  Instalación Deportiva Básica Avenida de Cerro ...
# 3  11350990  Instalación Deportiva Básica Avenida de las Su...
# 4  11350948  Instalación Deportiva Básica Avenida del Ensan...
#
#   DESCRIPCION-ENTIDAD HORARIO  \
# 0                 NaN     NaN
# 1                 NaN     NaN
# 2                 NaN     NaN
# 3                 NaN     NaN
# 4                 NaN     NaN
#
#                                         EQUIPAMIENTO  \
# 0         Pista de baloncesto. Pista de fútbol sala.
# 1  Pista polideportiva (marcajes de fútbol sala y...
# 2       Pista de minibaloncesto. Pista de minifútbol
# 3  Pista de baloncesto. Pista polideportiva (marc...
# 4  Pista de minibaloncesto. Pista de minifútbol. ...
#
#                                TRANSPORTE DESCRIPCION  ACCESIBILIDAD  \
# 0  Bus: 58 , 63 , 145Renfe: Santa Eugenia         NaN              0
# 1                      Metro: Las Suertes         NaN              0
# 2                 Metro: CongostoBus: 142         NaN              0
# 3                      Metro: Las Suertes         NaN              0
# 4                      Metro: Las Suertes         NaN              0
#
#                                          CONTENT-URL              NOMBRE-VIA  \
# 0  http://www.madrid.es/sites/v/index.jsp?vgnextc...     EMBALSE DE SAN JUAN
# 1  http://www.madrid.es/sites/v/index.jsp?vgnextc...         ALTO DEL RETIRO
# 2  http://www.madrid.es/sites/v/index.jsp?vgnextc...            CERRO MILANO
# 3  http://www.madrid.es/sites/v/index.jsp?vgnextc...  avenida de las Suertes
# 4  http://www.madrid.es/sites/v/index.jsp?vgnextc...    ENSANCHE DE VALLECAS
#
#    ...    pk_ins                                  Place of interest  \
# 0  ...  11353987  Instalación Deportiva  Básica Embalse de San Juan
# 1  ...   6344681       Instalación Deportiva Básica Alto del Retiro
# 2  ...  11350944  Instalación Deportiva Básica Avenida de Cerro ...
# 3  ...  11350990  Instalación Deportiva Básica Avenida de las Su...
# 4  ...  11350948  Instalación Deportiva Básica Avenida del Ensan...
#
#   ins_latitude  ins_longitude bicimad_latitude  bicimad_longitude  \
# 0    40.362643      -3.598148        40.400368          -3.634587
# 1    40.367515      -3.588265        40.400368          -3.634587
# 2    40.368619      -3.618357        40.400368          -3.634587
# 3    40.370297      -3.612067        40.400368          -3.634587
# 4    40.370297      -3.612067        40.400368          -3.634587
#
#       distance                  Station location Station ID  BiciMAD station
# 0  5844.283277  Calle Hacienda de Pavones nº 342      229.0          Pavones
# 1  6330.202181  Calle Hacienda de Pavones nº 342      229.0          Pavones
# 2  3970.966146  Calle Hacienda de Pavones nº 342      229.0          Pavones
# 3  4185.103648  Calle Hacienda de Pavones nº 342      229.0          Pavones
# 4  4185.103648  Calle Hacienda de Pavones nº 342      229.0          Pavones
#
# [5 rows x 41 columns]

# %%
nearest_bicimad_station= ins_nearest_stations[["Place of interest","CLASE-VIAL","NOMBRE-VIA","NUM","BiciMAD station","Station location"]] #We take just the columns we need for the final result table
nearest_bicimad_station["Place address"]=ins_nearest_stations["CLASE-VIAL"]+" "+ins_nearest_stations["NOMBRE-VIA"] +" "+ ins_nearest_stations["NUM"].fillna("s/n") #Put all address information in 1 column
result_nearest_station = nearest_bicimad_station[nearest_bicimad_station.columns[[0,6,4,5]]] #Take only the columns we need for the final result, and order them as per initial requeriment
result_nearest_station.to_csv("../data/results/result_nearest_station.csv", index=False) #Save the result table in csv
result_nearest_station.head()
# Out:
# /Users/ivan.repilado/miniconda3/envs/ironhack/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                    Place of interest  \
# 0  Instalación Deportiva  Básica Embalse de San Juan
# 1       Instalación Deportiva Básica Alto del Retiro
# 2  Instalación Deportiva Básica Avenida de Cerro ...
# 3  Instalación Deportiva Básica Avenida de las Su...
# 4  Instalación Deportiva Básica Avenida del Ensan...
#
#                         Place address BiciMAD station  \
# 0         CALLE EMBALSE DE SAN JUAN 1         Pavones
# 1            CALLE ALTO DEL RETIRO 13         Pavones
# 2              AVENIDA CERRO MILANO 1         Pavones
# 3  AVENIDA avenida de las Suertes s/n         Pavones
# 4     AVENIDA ENSANCHE DE VALLECAS 11         Pavones
#
#                    Station location
# 0  Calle Hacienda de Pavones nº 342
# 1  Calle Hacienda de Pavones nº 342
# 2  Calle Hacienda de Pavones nº 342
# 3  Calle Hacienda de Pavones nº 342
# 4  Calle Hacienda de Pavones nº 342

# %% [markdown]
# Creación del link como llegar de google?
# https://www.google.com/maps/dir/'40.479033,-3.708264'/40.463028,-3.69733/@40.479033,-3.708264,17z/data=!3m1!4b1!4m7!4m6!1m3!2m2!1d-3.708264!2d40.479033!1m0!3e2
#
#
# https://www.google.com/maps/dir/'40.398247,-3.716591'/40.3992778,-3.7188333/@40.3984601,-3.7201027,17z/data=!3m1!4b1!4m7!4m6!1m3!2m2!1d-3.716591!2d40.398247!1m0!3e2
#
# https://www.google.com/maps/dir/'ins_latitude,ins_longitude'/bicimad_latitude,bicimad_longitude/@ins_latitude,ins_longitude,17z/data=!3m1!4b1!4m7!4m6!1m3!2m2!1dins_longitude!2dins_latitude!1m0!3e2
